# %%
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()

df_columbia_1h_2025 = pd.read_sql("select * from auto.vi_test_summary_unified_reporting tsr join md2.test_types tt using (test_type_id) where tsr.collection_set_id = 12698 and tsr.test_type_id in (19, 20);",
                                      con=os.getenv('RSR_SVC_CONN'))

df_columbia_1h_2025.head()
# Out:
#    test_type_id  product_period_id product_period  collection_set_id
# 0            19                 37        2025-1H              12698  \
# 1            19                 37        2025-1H              12698
# 2            20                 37        2025-1H              12698
# 3            19                 37        2025-1H              12698
# 4            20                 37        2025-1H              12698
#
#         collection_set  test_event_id  device_event_id  collection_area_id
# 0  Columbia-SC_2025-1H      203230364       6797311158                 165  \
# 1  Columbia-SC_2025-1H      203230340       6797307992                 165
# 2  Columbia-SC_2025-1H      203230341       6797308080                 165
# 3  Columbia-SC_2025-1H      203230366       6797311745                 165
# 4  Columbia-SC_2025-1H      203230370       6797311964                 165
#
#    collection_type_id  carrier_id  ... task_speed_median
# ...

# %%
carrier_color_dict = {
                        'Verizon': '#b00000',
                        'AT&T': '#067ab4',
                        'T-Mobile': '#e60076',
                        'Sprint': '#ffaa00',
                        'Dish': '#3F3F3F',
                        'EE': '#2e9b9d',
                        'O2': '#010066',
                        'Three': '#000000',
                        'Vodafone': '#f80000',
                        'O2 UK': '#010066',
                        'Three UK': '#000000',
                        'Vodafone UK': '#f80000',
                        'Sunrise': '#d0606f',
                        'Swisscom': '#5b92cc',
                        'Salt': '#56bf83',
                        'ODIDO': '#FF7621',
                        'KPN': '#FFBB00',
                        'Vodafone NL': '#f80000',
                        'KT': '#FF7621',
                        'SK Telecom': '#FFBB00',
                        'LG U+': '#f80000',
                     }

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = df_columbia_1h_2025

sns.ecdfplot(data=df, x="task_speed_median", hue="carrier", palette=carrier_color_dict)
plt.title("Columbia-SC Carrier Download and Upload Speed Distribution (1H 2025)")
plt.xlabel("Upload Speed (Mbps) ")
plt.axhline(0.9)
plt.grid(True)
plt.savefig("Columbia-SC Carrier Download and Upload Speed Distribution (1H 2025)", format="png")
plt.show()
